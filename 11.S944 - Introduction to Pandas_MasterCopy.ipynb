# %% [markdown]
# ## 11.S944 Applied Urban Analytics - Pandas for Big Data
#
# ### Libraries are prewritten pieces of code to perform different tasks.
#
# <img src="images/pandas.jpg" width="650" align="middle">
#
# Pandas is the go-to Python library for Data Manipulation and Analysis.
# Pandas is awesome because it allows you to read data across various datatypes (including CSV, TSV, JSON, HTML etc) with huge file sizes.It has tons of different functions that make manipulating data a breeze. Some functions include merging and joining datasets as well as data cleaning by selecting and replacing columns.
# Pandas read Data into DataFrame (df), which is a two-dimensional data structure in the form of Rows and Columns. The official documentation is [here](https://dev.pandas.io/docs/user_guide/index.html).
#
# While learning to code is a long-term endeavor, this document aims to get you comfortable with running some of Panda's convenient built-in functions for data management. The following notebook is organised as follows, but <b> note that it is not a standard to query in the exact same order as this notebook when you embark on your own data later on. </b>
#
# ### Contents
# * 01 Introduction to Pandas - Reading in your Data
# * 02 Inspecting and Viewing your Data
# * 03 Data Cleaning
# * 04 Merging Datasets
# * 05 Manipulating Datasets and Saving to CSV
# * 06 More Pandas using Bluebike data & Visualizing Data (Optional)
#
#
# We will be using two sets of AirBnb data (Daily and Monthly) for Massachusetts downloaded from Harvard Dataverse.
#
# Download the folder 'data' under E3 from Stellar.
#
# _Make sure the datafiles are in the **same folder or directory as this notebook file.**_

# %% [markdown]
# ## 01- 01 Introduction to Pandas

# %% [markdown]
# Before using any library, we must import them into our notebook to proceed to bring into our Python environment. It is generally good practice to import all the libraries you need at the start of your notebook.

# %%
# Importing libraries [import LIBRARYNAME as ALIAS]
import pandas as pd

# %% [markdown]
# The Airbnb daily data is a CSV file with information on airbnb in Massachusetts across several years. The dataset is around 1.8GB - way too large to use in Excel.

# %%
# Reading in the data. Good to assign a variable so that you can just call the variable later on. 
# Variable here is called "airbnb_daily", but you could call it anything you like.

airbnb_daily = pd.read_csv("data\Airbnb_daily.csv") # Make sure file path is correct
# Out:
# C:\Users\kloen\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ***

# %% [markdown]
# ## 02 - 01  Inspecting and Viewing your Data

# %% [markdown]
# The first step after loading your data into a variable as a dataframe is to always inspect your data. Sometimes, errors such as wrongly imported column names will require you to add additional arguments to rectify when reading the data.
#
# Pandas offers a variety of attributes and methods to quickly view this data. You can access them by adding a period and the attribute or method name after the data frame variable, i.e.:
#
#     df_variable.attributes
#     df_variable.method()
#
# Make sure you pay attention to parentheses — they distinguish between an attribute (you can think about it as "who you are") and a method ("an action"), and the code won't work with or without, depending.
#
# Some essential attributes and methods for doing this are:
#
# * shape gives you dimensions
# * columns
# * index
# * value_counts()
# * values directly exposes the raw data
# * head() or tail() gives you the first or last 5 rows, by default. Changing the number argument inside gives you a specific number rows.
#
# More advanced but very useful are:
#
# * describe() gives you quick summary statistics
# * info() gives you a summary of data frame dimensions, column names and data types
# * mean(),sum(), count(), median() will also give you a quick intuition of your data

# %%
# Constantly checking the shape is a good practice - especially after manipulating with rows and columns
airbnb_daily.shape
# Out:
# (31349224, 10)

# %%
# Checking head of dataframe
airbnb_daily.head()
# Out:
#    Property ID        Date Status Booked Date  Price (USD)  Price (Native)  \
# 0  ab-10002366  2015-12-01      A         NaN        320.0           320.0
# 1  ab-10002366  2015-12-02      A         NaN        320.0           320.0
# 2  ab-10002366  2015-12-03      A         NaN        320.0           320.0
# 3  ab-10002366  2015-12-04      A         NaN        350.0           350.0
# 4  ab-10002366  2015-12-05      A         NaN        350.0           350.0
#
#   Currency Native  Reservation ID  Airbnb Property ID HomeAway Property ID
# 0             USD             NaN          10002366.0                  NaN
# 1             USD             NaN          10002366.0                  NaN
# 2             USD             NaN          10002366.0                  NaN
# 3             USD             NaN          10002366.0                  NaN
# 4             USD             NaN          10002366.0                  NaN

# %%
# Optional arguments inside parenthesis
airbnb_daily.head(10)
# Out:
#    Property ID        Date Status Booked Date  Price (USD)  Price (Native)  \
# 0  ab-10002366  2015-12-01      A         NaN        320.0           320.0
# 1  ab-10002366  2015-12-02      A         NaN        320.0           320.0
# 2  ab-10002366  2015-12-03      A         NaN        320.0           320.0
# 3  ab-10002366  2015-12-04      A         NaN        350.0           350.0
# 4  ab-10002366  2015-12-05      A         NaN        350.0           350.0
# 5  ab-10002366  2015-12-06      A         NaN        320.0           320.0
# 6  ab-10002366  2015-12-07      A         NaN        320.0           320.0
# 7  ab-10002366  2015-12-08      A         NaN        320.0           320.0
# 8  ab-10002366  2015-12-09      A         NaN        320.0           320.0
# 9  ab-10002366  2015-12-10      A         NaN        320.0           320.0
#
#   Currency Native  Reservation ID  Airbnb Property ID HomeAway Property ID
# 0             USD             NaN          10002366.0                  NaN
# 1             USD             NaN          10002366.0                  NaN
# 2             USD             NaN          10002366.0                  NaN
# 3             USD             NaN          10002366.0                  NaN
# 4             USD             NaN          10002366.0                  NaN
# 5             USD             NaN          10002366.0                  NaN
# 6             USD             NaN          10002366.0                  NaN
# 7             USD             NaN          10002366.0                  NaN
# 8             USD             NaN          10002366.0                  NaN
# 9             USD             NaN          10002366.0                  NaN

# %%
# Checking tail of dataframe
airbnb_daily.tail()
# Out:
#           Property ID        Date Status Booked Date  Price (USD)  \
# 31349219  ha-999689vb  2019-03-27      B         NaN        170.0
# 31349220  ha-999689vb  2019-03-28      B         NaN        170.0
# 31349221  ha-999689vb  2019-03-29      B         NaN        170.0
# 31349222  ha-999689vb  2019-03-30      B         NaN        170.0
# 31349223  ha-999689vb  2019-03-31      B         NaN        170.0
#
#           Price (Native) Currency Native  Reservation ID  Airbnb Property ID  \
# 31349219             NaN             NaN             NaN                 NaN
# 31349220             NaN             NaN             NaN                 NaN
# 31349221             NaN             NaN             NaN                 NaN
# 31349222             NaN             NaN             NaN                 NaN
# 31349223             NaN             NaN             NaN                 NaN
#
#          HomeAway Property ID
# 31349219             999689vb
# 31349220             999689vb
# 31349221             999689vb
# 31349222             999689vb
# 31349223             999689vb

# %%
# Information about each column in your dataframe. You would want to ensure that the column is in a format that is want - e.g. Prices should be in some form of numeric format
airbnb_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31349224 entries, 0 to 31349223
# Data columns (total 10 columns):
# Property ID             object
# Date                    object
# Status                  object
# Booked Date             object
# Price (USD)             float64
# Price (Native)          float64
# Currency Native         object
# Reservation ID          float64
# Airbnb Property ID      float64
# HomeAway Property ID    object
# dtypes: float64(4), object(6)
# memory usage: 2.3+ GB

# %%
# Describe - will work if there is at least one numeric column
# Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values
airbnb_daily.describe()
# Out:
#         Price (USD)  Price (Native)  Reservation ID  Airbnb Property ID
# count  3.115888e+07    2.891045e+07    5.457384e+06        2.898719e+07
# mean   1.758420e+02    1.805253e+02    1.412273e+08        1.293346e+07
# std    2.551404e+02    6.953560e+03    9.582017e+07        7.758475e+06
# min    0.000000e+00    1.000000e+00    2.900000e+01        8.830000e+02
# 25%    7.100000e+01    7.000000e+01    5.567376e+07        6.539902e+06
# 50%    1.200000e+02    1.100000e+02    1.309271e+08        1.300455e+07
# 75%    2.020000e+02    1.990000e+02    2.228092e+08        1.894810e+07
# max    2.000000e+04    4.705868e+06    3.331125e+08        3.399236e+07

# %% [markdown]
# ***

# %% [markdown]
# ## 02 - 02 Accessing specific sections of the Dataframe
# You can return a specific column via:
#
#     df_variable["column name"]
#
# Return a range of rows via:
#
#     df_variable[start row : end row]
#
#
# #### Some options to select and index rows and columns in Pandas.
#
# * .iloc - Selecting data by the row number(particular positions, will only take integers)
# * .loc - Selecting data by label or a condition
# * .idx - idxmax() returns row or column label where maximum value is located, idxmin() returns row or column label where minimum value is located

# %%
airbnb_daily.columns
# Out:
# Index(['Property ID', 'Date', 'Status', 'Booked Date', 'Price (USD)',
#        'Price (Native)', 'Currency Native', 'Reservation ID',
#        'Airbnb Property ID', 'HomeAway Property ID'],
#       dtype='object')

# %%
# Return column named 'Date'
airbnb_daily['Date']
# Out:
# 0           2015-12-01
# 1           2015-12-02
# 2           2015-12-03
# 3           2015-12-04
# 4           2015-12-05
#                ...
# 31349219    2019-03-27
# 31349220    2019-03-28
# 31349221    2019-03-29
# 31349222    2019-03-30
# 31349223    2019-03-31
# Name: Date, Length: 31349224, dtype: object

# %%
# Selecting specific columns of your dataframe 
# Double Bracket Frames: Outer bracket indicates selection of column, Inner Brackets indicates a list
airbnb_daily[['Property ID', 'Status', 'Price (USD)']]
# Out:
#           Property ID Status  Price (USD)
# 0         ab-10002366      A        320.0
# 1         ab-10002366      A        320.0
# 2         ab-10002366      A        320.0
# 3         ab-10002366      A        350.0
# 4         ab-10002366      A        350.0
# ...               ...    ...          ...
# 31349219  ha-999689vb      B        170.0
# 31349220  ha-999689vb      B        170.0
# 31349221  ha-999689vb      B        170.0
# 31349222  ha-999689vb      B        170.0
# 31349223  ha-999689vb      B        170.0
#
# [31349224 rows x 3 columns]

# %%
# QUIZ: Combining selection methods - get the head as well as the columns 'Property ID' and Reservation ID' 
airbnb_daily.head()[['Property ID','Airbnb Property ID']]
# Out:
#    Property ID  Airbnb Property ID
# 0  ab-10002366          10002366.0
# 1  ab-10002366          10002366.0
# 2  ab-10002366          10002366.0
# 3  ab-10002366          10002366.0
# 4  ab-10002366          10002366.0

# %%
# Finding out what does status mean? - Available, Blocked, Reserved, Unavailable
airbnb_daily['Status'].unique()
# Out:
# array(['A', 'B', 'R', 'U'], dtype=object)

# %%
# Finding out unique count values of each element
airbnb_daily['Status'].value_counts()
# Out:
# A    12348103
# B    12095289
# R     5580532
# U     1325300
# Name: Status, dtype: int64

# %%
# Number of unique values in the column 'Date'
airbnb_daily['Date'].nunique()
# Out:
# 1643

# %%
airbnb_daily.head(11)[["Date", "Status"]]
# Out:
#           Date Status
# 0   2015-12-01      A
# 1   2015-12-02      A
# 2   2015-12-03      A
# 3   2015-12-04      A
# 4   2015-12-05      A
# 5   2015-12-06      A
# 6   2015-12-07      A
# 7   2015-12-08      A
# 8   2015-12-09      A
# 9   2015-12-10      A
# 10  2015-12-11      A

# %%
# iloc (Positions) vs loc (Labels)
airbnb_daily.iloc[0:10]
# Out:
#    Property ID        Date Status Booked Date  Price (USD)  Price (Native)  \
# 0  ab-10002366  2015-12-01      A         NaN        320.0           320.0
# 1  ab-10002366  2015-12-02      A         NaN        320.0           320.0
# 2  ab-10002366  2015-12-03      A         NaN        320.0           320.0
# 3  ab-10002366  2015-12-04      A         NaN        350.0           350.0
# 4  ab-10002366  2015-12-05      A         NaN        350.0           350.0
# 5  ab-10002366  2015-12-06      A         NaN        320.0           320.0
# 6  ab-10002366  2015-12-07      A         NaN        320.0           320.0
# 7  ab-10002366  2015-12-08      A         NaN        320.0           320.0
# 8  ab-10002366  2015-12-09      A         NaN        320.0           320.0
# 9  ab-10002366  2015-12-10      A         NaN        320.0           320.0
#
#   Currency Native  Reservation ID  Airbnb Property ID HomeAway Property ID
# 0             USD             NaN          10002366.0                  NaN
# 1             USD             NaN          10002366.0                  NaN
# 2             USD             NaN          10002366.0                  NaN
# 3             USD             NaN          10002366.0                  NaN
# 4             USD             NaN          10002366.0                  NaN
# 5             USD             NaN          10002366.0                  NaN
# 6             USD             NaN          10002366.0                  NaN
# 7             USD             NaN          10002366.0                  NaN
# 8             USD             NaN          10002366.0                  NaN
# 9             USD             NaN          10002366.0                  NaN

# %%
# Get Data and Status for the first 10 rows in the data set
airbnb_daily.loc[0:10, ["Date", "Status"]]
# Out:
#           Date Status
# 0   2015-12-01      A
# 1   2015-12-02      A
# 2   2015-12-03      A
# 3   2015-12-04      A
# 4   2015-12-05      A
# 5   2015-12-06      A
# 6   2015-12-07      A
# 7   2015-12-08      A
# 8   2015-12-09      A
# 9   2015-12-10      A
# 10  2015-12-11      A

# %%
# QUIZ: Get Date and Price (USD) for 15000th entry
airbnb_daily.loc[15000, ['Date', "Price (USD)"]]
# Out:
# Date           2017-10-21
# Price (USD)           600
# Name: 15000, dtype: object

# %% [markdown]
# ## 03 - 01  Cleaning your Data

# %% [markdown]
# Depending on the source, datasets are often messy or incomplete, containing strange characters or null values alongside incorrect entries. Do not be deterred though - the process of cleaning is a great way to understand and gain insights on your data before you proceed to analysize them. Pandas is a great tool to utilize to clean up messy data.
#
# #### Some methods include:
#
# * isna() or isnull() to check for entries with NaN
# * dropna() to drop data that are NaN
# * dropna(axis=1) to drop columns
# * fillna(x) to fill all the NaN with X, any number that you choose e.g. the mean
# * replace()
# * astype() to change datatype of specific column

# %%
airbnb_daily.head()
# Out:
#    Property ID        Date Status Booked Date  Price (USD)  Price (Native)  \
# 0  ab-10002366  2015-12-01      A         NaN        320.0           320.0
# 1  ab-10002366  2015-12-02      A         NaN        320.0           320.0
# 2  ab-10002366  2015-12-03      A         NaN        320.0           320.0
# 3  ab-10002366  2015-12-04      A         NaN        350.0           350.0
# 4  ab-10002366  2015-12-05      A         NaN        350.0           350.0
#
#   Currency Native  Reservation ID  Airbnb Property ID HomeAway Property ID
# 0             USD             NaN          10002366.0                  NaN
# 1             USD             NaN          10002366.0                  NaN
# 2             USD             NaN          10002366.0                  NaN
# 3             USD             NaN          10002366.0                  NaN
# 4             USD             NaN          10002366.0                  NaN

# %%
# Dropping unnecessary columns using df.drop - note the argument of inplace=True!
airbnb_daily.drop(columns= ['Price (Native)', 'Currency Native', 'HomeAway Property ID', 'Airbnb Property ID'], inplace=True)
airbnb_daily.head()
# Out:
#    Property ID        Date Status Booked Date  Price (USD)  Reservation ID
# 0  ab-10002366  2015-12-01      A         NaN        320.0             NaN
# 1  ab-10002366  2015-12-02      A         NaN        320.0             NaN
# 2  ab-10002366  2015-12-03      A         NaN        320.0             NaN
# 3  ab-10002366  2015-12-04      A         NaN        350.0             NaN
# 4  ab-10002366  2015-12-05      A         NaN        350.0             NaN

# %%
# Renaming columns 
airbnb_daily = airbnb_daily.rename(columns={"Price (USD)": "Price", "Property ID":"Property_ID", "Booked Date":"Booked_Date", "Reservation ID":"Reservation_ID"})

# %%
airbnb_daily['Date'].dtype
# Out:
# dtype('O')

# %%
# Changing to datetime format - a unique format in Pandas that allow us to manipulate time series based operation on the dates
airbnb_daily['Date']=pd.to_datetime(airbnb_daily['Date'])

# %%
airbnb_daily['Date'].min()
# Out:
# Timestamp('2014-10-01 00:00:00')

# %%
# Taking only data for Year 2018
airbnb_sub = (airbnb_daily['Date'] >= '2018-01-01') & (airbnb_daily['Date'] <= '2018-12-31')
daily_2018 = airbnb_daily.loc[airbnb_sub]

# %%
# Quiz: check the shape of daily_2018
daily_2018.shape
# Out:
# (10851011, 6)

# %%
# Quiz: check the head and tail of daily_2018
daily_2018.tail()
# Out:
#           Property_ID       Date Status Booked_Date  Price  Reservation_ID
# 31349129  ha-999689vb 2018-12-27      B         NaN  170.0             NaN
# 31349130  ha-999689vb 2018-12-28      B         NaN  170.0             NaN
# 31349131  ha-999689vb 2018-12-29      B         NaN  170.0             NaN
# 31349132  ha-999689vb 2018-12-30      B         NaN  170.0             NaN
# 31349133  ha-999689vb 2018-12-31      A         NaN  170.0             NaN

# %%
# Quiz: check the mean of column 'price'. Hint: df['column'].method()
daily_2018['Price'].mean()
# Out:
# 186.7495538376083

# %%
daily_2018['Date'].min(), daily_2018['Date'].max()
# Out:
# (Timestamp('2018-01-01 00:00:00'), Timestamp('2018-12-31 00:00:00'))

# %%
# Making sure my data is clean
print('There are', daily_2018['Date'].nunique(), 'days and', daily_2018['Reservation_ID'].nunique(), 'unique listings in the dataset.')
# Out:
# There are 365 days and 537207 unique listings in the dataset.

# %%
# Finding out the most expensive and cheapest apartment listed in 2018
daily_2018[daily_2018['Price']==daily_2018['Price'].max()]
# Out:
#          Property_ID       Date Status Booked_Date    Price  Reservation_ID
# 30963479  ha-7250451 2018-08-22      A         NaN  20000.0             NaN
# 30963480  ha-7250451 2018-08-23      A         NaN  20000.0             NaN

# %%
daily_2018[daily_2018['Price']==daily_2018['Price'].min()]
# Out:
#            Property_ID       Date Status Booked_Date  Price  Reservation_ID
# 29163492  ha-1152882vb 2018-08-03      R  2018-05-06    1.0      14548118.0
# 29274355  ha-1285181vb 2018-09-09      B         NaN    1.0             NaN
# 29274356  ha-1285181vb 2018-09-10      B         NaN    1.0             NaN
# 29274357  ha-1285181vb 2018-09-11      B         NaN    1.0             NaN
# 29274358  ha-1285181vb 2018-09-12      B         NaN    1.0             NaN
# ...                ...        ...    ...         ...    ...             ...
# 29274468  ha-1285181vb 2018-12-31      B         NaN    1.0             NaN
# 29470435     ha-291919 2018-06-16      R         NaN    1.0             NaN
# 29470436     ha-291919 2018-06-17      R         NaN    1.0             NaN
# 29470437     ha-291919 2018-06-18      R         NaN    1.0             NaN
# 31070105   ha-830273vb 2018-09-05      R  2018-08-20    1.0      75852030.0
#
# [119 rows x 6 columns]

# %%
# Replace outliers which may be incorrect data, find by slicing methods (loc and iloc)
daily_2018.loc[daily_2018['Property_ID'] == 'ha-7250451']
# Out:
#          Property_ID       Date Status Booked_Date  Price  Reservation_ID
# 30963458  ha-7250451 2018-08-01      U         NaN    NaN             NaN
# 30963459  ha-7250451 2018-08-02      U         NaN    NaN             NaN
# 30963460  ha-7250451 2018-08-03      U         NaN    NaN             NaN
# 30963461  ha-7250451 2018-08-04      U         NaN    NaN             NaN
# 30963462  ha-7250451 2018-08-05      U         NaN    NaN             NaN
# ...              ...        ...    ...         ...    ...             ...
# 30963606  ha-7250451 2018-12-27      A         NaN  600.0             NaN
# 30963607  ha-7250451 2018-12-28      A         NaN  600.0             NaN
# 30963608  ha-7250451 2018-12-29      A         NaN  600.0             NaN
# 30963609  ha-7250451 2018-12-30      A         NaN  600.0             NaN
# 30963610  ha-7250451 2018-12-31      A         NaN  600.0             NaN
#
# [153 rows x 6 columns]

# %%
daily_2018['Price'].replace(['20000.0'],600)
# Out:
# 1190        350.0
# 1191        350.0
# 1192        225.0
# 1193        225.0
# 1194        225.0
#             ...
# 31349129    170.0
# 31349130    170.0
# 31349131    170.0
# 31349132    170.0
# 31349133    170.0
# Name: Price, Length: 10851011, dtype: float64

# %%
# Check again for any other possible outliers
daily_2018.sort_values(by='Price', ascending=False)
# Out:
#            Property_ID       Date Status Booked_Date    Price  Reservation_ID
# 30963479    ha-7250451 2018-08-22      A         NaN  20000.0             NaN
# 30963480    ha-7250451 2018-08-23      A         NaN  20000.0             NaN
# 29318849  ha-1372928vb 2018-09-24      B         NaN  17400.0             NaN
# 30786397   ha-599988vb 2018-07-09      A         NaN  10612.0             NaN
# 30786398   ha-599988vb 2018-07-10      A         NaN  10612.0             NaN
# ...                ...        ...    ...         ...      ...             ...
# 31310804     ha-981595 2018-06-18      A         NaN      NaN             NaN
# 31310805     ha-981595 2018-06-19      A         NaN      NaN             NaN
# 31310806     ha-981595 2018-06-20      A         NaN      NaN             NaN
# 31310807     ha-981595 2018-06-21      A         NaN      NaN             NaN
# 31310808     ha-981595 2018-06-22      A         NaN      NaN             NaN
#
# [10851011 rows x 6 columns]

# %%
daily_2018['Price'].median()
# Out:
# 125.0

# %%
# Simply replacing Prices below 40 and above 2000 per day with the median price of the dataset 
# There is a flaw with doing so before throwing out all the outliers, but for quick demonstration purposes we will work with this

mask = (daily_2018['Price']>= 4000) | (daily_2018['Price'] <= 40)
daily_2018.loc[mask] = 125
daily_2018.sort_values(by='Price', ascending=False)
# Out:
# C:\Users\kloen\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#           Property_ID                 Date Status Booked_Date   Price  \
# 4103405   ab-13657486  2018-06-10 00:00:00      A         NaN  3999.0
# 4103360   ab-13657486  2018-04-26 00:00:00      A         NaN  3999.0
# 4103362   ab-13657486  2018-04-28 00:00:00      A         NaN  3999.0
# 4103363   ab-13657486  2018-04-29 00:00:00      A         NaN  3999.0
# 4103364   ab-13657486  2018-04-30 00:00:00      A         NaN  3999.0
# ...               ...                  ...    ...         ...     ...
# 31310804    ha-981595  2018-06-18 00:00:00      A         NaN     NaN
# 31310805    ha-981595  2018-06-19 00:00:00      A         NaN     NaN
# 31310806    ha-981595  2018-06-20 00:00:00      A         NaN     NaN
# 31310807    ha-981595  2018-06-21 00:00:00      A         NaN     NaN
# 31310808    ha-981595  2018-06-22 00:00:00      A         NaN     NaN
#
#           Reservation_ID
# 4103405              NaN
# 4103360              NaN
# 4103362              NaN
# 4103363              NaN
# 4103364              NaN
# ...                  ...
# 31310804             NaN
# 31310805             NaN
# 31310806             NaN
# 31310807             NaN
# 31310808             NaN
#
# [10851011 rows x 6 columns]

# %%
daily_2018['Price'].min()
# Out:
# 41.0

# %%
daily_2018['Price'].max()
# Out:
# 3999.0

# %% [markdown]
# ***

# %% [markdown]
# ## 04 - 01 Merging Datasets

# %% [markdown]
# There are three main ways of combining DataFrames together (Merge, Join, Concat):
# * pd.merge - Merging based on columns or indexes (with default behaviour joining on columns)
# * df.join - Joining based on columns or indexes, similiar to Merge (with default behaviour joining on indexes)
# * pd.concat - Concating your DataFrames Vertically

# %% [markdown]
# While the airbnb_daily dataset was interesting, it lacked several information that would be helpful later on ,such as the Latitude and Longitude for each property. We can thus utilise another dataset, airbnb_monthly, that has more information and when joined together, will give us a more comprehensive idea of the airbnb scenario in Massachusetts.

# %%
# Read in the airbnb_monthly dataset
airbnb_monthly = pd.read_csv("data\Airbnb_monthly.csv")
# Out:
# C:\Users\kloen\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Look at the first and last 10 rows of the data
airbnb_monthly.head(10)
# Out:
#   Property ID Property Type     Listing Type  Bedrooms Reporting Month  \
# 0      ab-883     Apartment  Entire home/apt       0.0      2014-10-01
# 1      ab-883     Apartment  Entire home/apt       0.0      2014-11-01
# 2      ab-883     Apartment  Entire home/apt       0.0      2014-12-01
# 3      ab-883     Apartment  Entire home/apt       0.0      2015-01-01
# 4      ab-883     Apartment  Entire home/apt       0.0      2015-02-01
# 5      ab-883     Apartment  Entire home/apt       0.0      2015-03-01
# 6      ab-883     Apartment  Entire home/apt       0.0      2015-04-01
# 7      ab-883     Apartment  Entire home/apt       0.0      2015-05-01
# 8      ab-883     Apartment  Entire home/apt       0.0      2015-06-01
# 9      ab-883     Apartment  Entire home/apt       0.0      2015-07-01
#
#    Occupancy Rate  Revenue (USD)  Revenue (Native)  ADR (USD)  ADR (Native)  \
# 0           0.267         590.00            590.00     147.50        147.50
# 1             NaN            NaN               NaN        NaN           NaN
# 2             NaN            NaN               NaN        NaN           NaN
# 3             NaN            NaN               NaN        NaN           NaN
# 4             NaN            NaN               NaN        NaN           NaN
# 5             NaN            NaN               NaN        NaN           NaN
# 6           0.000            NaN               NaN        NaN           NaN
# 7           0.211         554.29            554.29     138.57        138.57
# 8           0.562        1348.21           1348.21     149.80        149.80
# 9           0.333         152.50            152.50     152.50        152.50
#
#    ...              Metropolitan Statistical Area  Latitude  Longitude  \
# 0  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 1  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 2  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 3  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 4  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 5  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 6  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 7  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 8  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
# 9  ...  Boston-Cambridge-Newton, MA-NH Metro Area  42.65736  -70.62181
#
#    Active Scraped During Month Currency Native Airbnb Property ID  \
# 0    True                 True             USD              883.0
# 1   False                 True             USD              883.0
# 2   False                False             USD              883.0
# 3   False                 True             USD              883.0
# 4   False                 True             USD              883.0
# 5   False                 True             USD              883.0
# 6    True                 True             USD              883.0
# 7    True                 True             USD              883.0
# 8    True                 True             USD              883.0
# 9    True                 True             USD              883.0
#
#    Airbnb Host ID HomeAway Property ID HomeAway Property Manager
# 0          1112.0                  NaN                       NaN
# 1          1112.0                  NaN                       NaN
# 2          1112.0                  NaN                       NaN
# 3          1112.0                  NaN                       NaN
# 4          1112.0                  NaN                       NaN
# 5          1112.0                  NaN                       NaN
# 6          1112.0                  NaN                       NaN
# 7          1112.0                  NaN                       NaN
# 8          1112.0                  NaN                       NaN
# 9          1112.0                  NaN                       NaN
#
# [10 rows x 29 columns]

# %%
# View the columns in the data
airbnb_monthly.columns
# Out:
# Index(['Property ID', 'Property Type', 'Listing Type', 'Bedrooms',
#        'Reporting Month', 'Occupancy Rate', 'Revenue (USD)',
#        'Revenue (Native)', 'ADR (USD)', 'ADR (Native)',
#        'Number of Reservations', 'Reservation Days', 'Available Days',
#        'Blocked Days', 'Country', 'State', 'City', 'Zipcode', 'Neighborhood',
#        'Metropolitan Statistical Area', 'Latitude', 'Longitude', 'Active',
#        'Scraped During Month', 'Currency Native', 'Airbnb Property ID',
#        'Airbnb Host ID', 'HomeAway Property ID', 'HomeAway Property Manager'],
#       dtype='object')

# %%
# Too many columns that we dont need. Instead of dropping them, we can also choose only the columns we want when reading in the data
airbnb_monthly = pd.read_csv("data\Airbnb_monthly.csv", usecols=['Property ID', 'Property Type', 'Listing Type', 'Bedrooms',
       'Reporting Month', 'Occupancy Rate', 'Revenue (USD)','Number of Reservations', 'Reservation Days', 'Available Days',
       'Blocked Days', 'Country', 'State', 'City', 'Zipcode', 'Neighborhood','Latitude', 'Longitude'])

# %%
# Find out the Shape
airbnb_monthly.shape
# Out:
# (953429, 18)

# %%
# Find out the information
airbnb_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953429 entries, 0 to 953428
# Data columns (total 18 columns):
# Property ID               953429 non-null object
# Property Type             952705 non-null object
# Listing Type              953015 non-null object
# Bedrooms                  952673 non-null float64
# Reporting Month           953429 non-null object
# Occupancy Rate            853443 non-null float64
# Revenue (USD)             730605 non-null float64
# Number of Reservations    953429 non-null int64
# Reservation Days          953429 non-null int64
# Available Days            953429 non-null int64
# Blocked Days              953429 non-null int64
# Country                   953422 non-null object
# State                     953422 non-null object
# City                      948753 non-null object
# Zipcode                   948760 non-null float64
# Neighborhood              389580 non-null object
# Latitude                  953429 non-null float64
# Longitude                 953429 non-null float64
# dtypes: float64(6), int64(4), object(8)
# memory usage: 130.9+ MB

# %%
# Changing to datetime format
airbnb_monthly['Reporting Month']= pd.to_datetime(airbnb_monthly['Reporting Month'])

# %%
# Extract data only for the year of 2018
monthly_sub = (airbnb_monthly['Reporting Month']>= '2018-01-01') & (airbnb_monthly['Reporting Month'] <= '2018-12-31')
monthly_2018 = airbnb_monthly.loc[monthly_sub]
monthly_2018.head()
# Out:
#    Property ID Property Type     Listing Type  Bedrooms Reporting Month  \
# 39      ab-883     Apartment  Entire home/apt       0.0      2018-01-01
# 40      ab-883     Apartment  Entire home/apt       0.0      2018-02-01
# 41      ab-883     Apartment  Entire home/apt       0.0      2018-03-01
# 42      ab-883     Apartment  Entire home/apt       0.0      2018-04-01
# 43      ab-883     Apartment  Entire home/apt       0.0      2018-05-01
#
#     Occupancy Rate  Revenue (USD)  Number of Reservations  Reservation Days  \
# 39           1.000         2420.0                       2                18
# 40           0.000            0.0                       0                 0
# 41           0.000            0.0                       0                 0
# 42           0.000            0.0                       0                 0
# 43           0.581         2384.0                       5                18
#
#     Available Days  Blocked Days        Country          State      City  \
# 39               0            13  United States  Massachusetts  Rockport
# 40               0            28  United States  Massachusetts  Rockport
# 41               0            31  United States  Massachusetts  Rockport
# 42               0            30  United States  Massachusetts  Rockport
# 43              13             0  United States  Massachusetts  Rockport
#
#     Zipcode Neighborhood  Latitude  Longitude
# 39   1966.0          NaN  42.65736  -70.62181
# 40   1966.0          NaN  42.65736  -70.62181
# 41   1966.0          NaN  42.65736  -70.62181
# 42   1966.0          NaN  42.65736  -70.62181
# 43   1966.0          NaN  42.65736  -70.62181

# %%
monthly_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336980 entries, 39 to 953425
# Data columns (total 18 columns):
# Property ID               336980 non-null object
# Property Type             336881 non-null object
# Listing Type              336927 non-null object
# Bedrooms                  336864 non-null float64
# Reporting Month           336980 non-null datetime64[ns]
# Occupancy Rate            336980 non-null float64
# Revenue (USD)             336831 non-null float64
# Number of Reservations    336980 non-null int64
# Reservation Days          336980 non-null int64
# Available Days            336980 non-null int64
# Blocked Days              336980 non-null int64
# Country                   336976 non-null object
# State                     336976 non-null object
# City                      335384 non-null object
# Zipcode                   335388 non-null float64
# Neighborhood              128591 non-null object
# Latitude                  336980 non-null float64
# Longitude                 336980 non-null float64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(7)
# memory usage: 48.8+ MB

# %%
monthly_2018['City'].unique()
# Out:
# array(['Rockport', 'Waltham', 'Boston', 'Roxbury', 'Roslindale',
#        'Cambridge', 'Somerville', 'Roxbury Crossing', 'Chelsea', nan,
#        'Allston', 'Salem', 'Newton Center', 'Dorchester', 'Beverly',
#        'Millis', 'Brookline', 'Jamaica Plain', 'Charlestown',
#        'Newton Highlands', 'Medford', 'North Weymouth', 'Onset', 'Newton',
#        'Malden', 'Concord', 'Swampscott', 'Winthrop', 'Sudbury', 'Revere',
#        'Wareham', 'Sharon', 'Brighton', 'Lexington', 'Carver', 'Lawrence',
#        'Essex', 'Gloucester', 'Marblehead', 'Marion', 'West Roxbury',
#        'Lynn', 'Dorchester Center', 'Belmont', 'Dover', 'Manchester',
#        'Plymouth', 'Marlborough', 'Newburyport', 'Cohasset',
#        'West Newbury', 'Lowell', 'Hull', 'Groton', 'Wellesley',
#        'Newtonville', 'Nahant', 'Portsmouth', 'Haverhill', 'Rowley',
#        'Nottingham', 'South Hamilton', 'Milton', 'Scituate', 'Quincy',
#        'Arlington', 'Winchester', 'Needham', 'Watertown', 'West Newton',
#        'Framingham', 'Duxbury', 'Andover', 'Needham Heights', 'Woburn',
#        'Billerica', 'Everett', 'Acton', 'Waban', 'Deerfield', 'Mattapan',
#        'Londonderry', 'Natick', 'Sherborn', 'Holbrook', 'Marshfield',
#        'Chestnut Hill', 'Pepperell', 'Salisbury', 'Exeter', 'Stoneham',
#        'Kingston', 'Auburndale', 'Brockton', 'Canton', 'Wrentham',
#        'Byfield', 'Littleton', 'Ipswich', 'North Hampton', 'Rye',
#        'Hyde Park', 'Randolph', 'Dedham', 'Lincoln', 'Durham', 'Melrose',
#        'Lynnfield', 'Bedford', 'Saugus', 'Newton Lower Falls', 'Rockland',
#        'Wellesley Hills', 'Seabrook', 'Middleboro', 'Wayland', 'Derry',
#        'Lee', 'Westford', 'Danville', 'Mattapoisett', 'Weston', 'Walpole',
#        'Newbury', 'Norwood', 'Somersworth', 'Hampton', 'Buzzards Bay',
#        'Chelmsford', 'Wakefield', 'Bridgewater', 'Sandown', 'Topsfield',
#        'Avon', 'New Durham', 'Tewksbury', 'Hingham', 'Auburn', 'Ayer',
#        'Greenland', 'Farmington', 'Danvers', 'North Andover', 'Maynard',
#        'Raymond', 'Northwood', 'Rollinsford', 'New Castle', 'Plainville',
#        'Braintree', 'Stoughton', 'South Weymouth', 'Rochester',
#        'Hopkinton', 'Windham', 'Newmarket', 'Norwell', 'Medfield',
#        'Peabody', 'North Chelmsford', 'Foxboro', 'Lakeville',
#        'East Weymouth', 'Reading', 'Westwood', 'Dracut',
#        'Newton Upper Falls', 'Humarock', 'Wenham', 'Hanover', 'Stratham',
#        'Carlisle', 'Dunstable', 'Tyngsboro', 'Hampstead', 'Madbury',
#        'Ashland', 'Barrington', 'Franklin', 'Burlington', 'Shirley',
#        'Hampton Falls', 'North Reading', 'East Wareham', 'Georgetown',
#        'Amesbury', 'Middleton', 'Pembroke', 'Strafford', 'Atkinson',
#        'North Billerica', 'Merrimac', 'Boxford', 'Methuen', 'Groveland',
#        'Abington', 'Wilmington', 'Hudson', 'Weymouth', 'Epping', 'Candia',
#        'East Walpole', 'Plympton', 'East Kingston', 'West Townsend',
#        'Boxborough', 'Holliston', 'Norfolk', 'Ashby', 'Hanson', 'Medway',
#        'Stow', 'West Wareham', 'West Bridgewater', 'Townsend', 'Chester',
#        'East Bridgewater', 'Union', 'Hanscom Afb', 'Bellingham',
#        'Milton Mills', 'Village Of Nagog Woo', 'South Walpole', 'Whitman',
#        'Rye Beach'], dtype=object)

# %%
monthly_2018.to_csv('data\monthly_2018.csv')

# %%
cambridge = monthly_2018.loc[monthly_2018['City']=='Cambridge']
cambridge.head()
# Out:
#     Property ID Property Type  Listing Type  Bedrooms Reporting Month  \
# 486     ab-7149     Apartment  Private room       1.0      2018-01-01
# 487     ab-7149     Apartment  Private room       1.0      2018-02-01
# 488     ab-7149     Apartment  Private room       1.0      2018-03-01
# 489     ab-7149     Apartment  Private room       1.0      2018-04-01
# 490     ab-7149     Apartment  Private room       1.0      2018-05-01
#
#      Occupancy Rate  Revenue (USD)  Number of Reservations  Reservation Days  \
# 486             0.0            0.0                       0                 0
# 487             0.0            0.0                       0                 0
# 488             0.0            0.0                       0                 0
# 489             0.0            0.0                       0                 0
# 490             0.0            0.0                       0                 0
#
#      Available Days  Blocked Days        Country          State       City  \
# 486              31             0  United States  Massachusetts  Cambridge
# 487              28             0  United States  Massachusetts  Cambridge
# 488              31             0  United States  Massachusetts  Cambridge
# 489              30             0  United States  Massachusetts  Cambridge
# 490              31             0  United States  Massachusetts  Cambridge
#
#      Zipcode Neighborhood   Latitude  Longitude
# 486   2139.0    Cambridge  42.366173 -71.097865
# 487   2139.0    Cambridge  42.366173 -71.097865
# 488   2139.0    Cambridge  42.366173 -71.097865
# 489   2139.0    Cambridge  42.366173 -71.097865
# 490   2139.0    Cambridge  42.366173 -71.097865

# %%
cambridge.columns
# Out:
# Index(['Property ID', 'Property Type', 'Listing Type', 'Bedrooms',
#        'Reporting Month', 'Occupancy Rate', 'Revenue (USD)',
#        'Number of Reservations', 'Reservation Days', 'Available Days',
#        'Blocked Days', 'Country', 'State', 'City', 'Zipcode', 'Neighborhood',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
# Making sure dataset is left with cambridge city
cambridge['Zipcode'].unique()
# Out:
# array([2139., 2138., 2142., 2140., 2141.])

# %%
daily_2018.head()
# Out:
#       Property_ID                 Date Status Booked_Date  Price  \
# 1190  ab-10004575  2018-01-01 00:00:00      A         NaN  350.0
# 1191  ab-10004575  2018-01-02 00:00:00      A         NaN  350.0
# 1192  ab-10004575  2018-01-03 00:00:00      A         NaN  225.0
# 1193  ab-10004575  2018-01-04 00:00:00      A         NaN  225.0
# 1194  ab-10004575  2018-01-05 00:00:00      A         NaN  225.0
#
#       Reservation_ID
# 1190             NaN
# 1191             NaN
# 1192             NaN
# 1193             NaN
# 1194             NaN

# %%
daily_2018.loc[daily_2018['Property_ID'] == 'ab-10010212'].count()
# Out:
# Property_ID       120
# Date              120
# Status            120
# Booked_Date         0
# Price             120
# Reservation_ID      0
# dtype: int64

# %%
cambridge_joined = daily_2018.merge(cambridge[['Property ID', 'Zipcode', 'Latitude', 'Longitude']], left_on="Property_ID", right_on="Property ID")
cambridge_joined.head()
# Out:
#    Property_ID                 Date Status Booked_Date  Price  Reservation_ID  \
# 0  ab-10010212  2018-01-01 00:00:00      B         NaN   41.0             NaN
# 1  ab-10010212  2018-01-01 00:00:00      B         NaN   41.0             NaN
# 2  ab-10010212  2018-01-01 00:00:00      B         NaN   41.0             NaN
# 3  ab-10010212  2018-01-01 00:00:00      B         NaN   41.0             NaN
# 4  ab-10010212  2018-01-02 00:00:00      B         NaN   41.0             NaN
#
#    Property ID  Zipcode   Latitude  Longitude
# 0  ab-10010212   2139.0  42.362155 -71.107843
# 1  ab-10010212   2139.0  42.362155 -71.107843
# 2  ab-10010212   2139.0  42.362155 -71.107843
# 3  ab-10010212   2139.0  42.362155 -71.107843
# 4  ab-10010212   2139.0  42.362155 -71.107843

# %%
cambridge_joined= cambridge_joined.drop_duplicates()

# %%
cambridge_joined.loc[cambridge_joined['Property_ID'] == 'ab-10010212'].count()
# Out:
# Property_ID       120
# Date              120
# Status            120
# Booked_Date         0
# Price             120
# Reservation_ID      0
# Property ID       120
# Zipcode           120
# Latitude          120
# Longitude         120
# dtype: int64

# %%
# According to Data Dictionary A = Available,  B = Blocked,  R = Reserved, U = Unavailable
cambridge_joined['Status'].unique()
# Out:
# array(['B', 'R', 'A', 'U'], dtype=object)

# %%
cambridge_joined.columns
# Out:
# Index(['Property_ID', 'Date', 'Status', 'Booked_Date', 'Price',
#        'Reservation_ID', 'Property ID', 'Zipcode', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
cambridge_joined.tail()
# Out:
#           Property_ID                 Date Status Booked_Date  Price  \
# 13744770  ha-983967vb  2018-12-27 00:00:00      B         NaN   95.0
# 13744782  ha-983967vb  2018-12-28 00:00:00      B         NaN   95.0
# 13744794  ha-983967vb  2018-12-29 00:00:00      B         NaN   95.0
# 13744806  ha-983967vb  2018-12-30 00:00:00      B         NaN   95.0
# 13744818  ha-983967vb  2018-12-31 00:00:00      A         NaN   95.0
#
#           Reservation_ID  Property ID  Zipcode   Latitude  Longitude
# 13744770             NaN  ha-983967vb   2140.0  42.386419 -71.117637
# 13744782             NaN  ha-983967vb   2140.0  42.386419 -71.117637
# 13744794             NaN  ha-983967vb   2140.0  42.386419 -71.117637
# 13744806             NaN  ha-983967vb   2140.0  42.386419 -71.117637
# 13744818             NaN  ha-983967vb   2140.0  42.386419 -71.117637

# %% [markdown]
# ### Groupby( ) splits the data into different groups depending on a variable of your choice

# %%
# Finding out the total number of entries per property in 2018
cambridge_joined.groupby(['Property_ID']).count()
# Out:
#              Date  Status  Booked_Date  Price  Reservation_ID  Property ID  \
# Property_ID
# ab-10010212   120     120            0    120               0          120
# ab-10022287   365     365            0    365               0          365
# ab-10031324   365     365           15    365              15          365
# ab-10031515   306     306           59    306              59          306
# ab-10041159   120     120            0    120               0          120
# ...           ...     ...          ...    ...             ...          ...
# ha-983963vb   365     365          102    365             102          365
# ha-983964vb   365     365          140    365             140          365
# ha-983965vb   365     365           93    365              93          365
# ha-983966vb   365     365          153    365             153          365
# ha-983967vb   365     365          239    365             239          365
#
#              Zipcode  Latitude  Longitude
# Property_ID
# ab-10010212      120       120        120
# ab-10022287      365       365        365
# ab-10031324      365       365        365
# ab-10031515      306       306        306
# ab-10041159      120       120        120
# ...              ...       ...        ...
# ha-983963vb      365       365        365
# ha-983964vb      365       365        365
# ha-983965vb      365       365        365
# ha-983966vb      365       365        365
# ha-983967vb      365       365        365
#
# [4610 rows x 9 columns]

# %%
# What is the total amount earned by each Property throughout the entire year?
cambridge_joined[cambridge_joined['Status'] == 'B'].groupby('Property_ID')['Price'].sum()
# Out:
# Property_ID
# ab-10010212     4920.0
# ab-10022287    43435.0
# ab-10031324    40080.0
# ab-10031515     4386.0
# ab-10041159     8040.0
#                 ...
# ha-983963vb    18716.0
# ha-983964vb    13520.0
# ha-983965vb    11634.0
# ha-983966vb    26500.0
# ha-983967vb    11495.0
# Name: Price, Length: 4108, dtype: float64

# %%
# Finding out the highest amount earned by the property
cambridge_joined[cambridge_joined['Status'] == 'B'].groupby('Property_ID')['Price'].sum().max()
# Out:
# 566036.0

# %%
# Finding out which property earned the highest
cambridge_joined[cambridge_joined['Status'] == 'B'].groupby('Property_ID')['Price'].sum().idxmax()
# Out:
# 'ha-4918992'

# %%
cambridge_joined.loc[cambridge_joined['Property_ID']== 'ha-4918992']
# Out:
#          Property_ID                 Date Status Booked_Date   Price  \
# 13594706  ha-4918992  2018-04-01 00:00:00      U         NaN     NaN
# 13594715  ha-4918992  2018-04-02 00:00:00      U         NaN     NaN
# 13594724  ha-4918992  2018-04-03 00:00:00      U         NaN     NaN
# 13594733  ha-4918992  2018-04-04 00:00:00      U         NaN     NaN
# 13594742  ha-4918992  2018-04-05 00:00:00      U         NaN     NaN
# ...              ...                  ...    ...         ...     ...
# 13597136  ha-4918992  2018-12-27 00:00:00      B         NaN  3000.0
# 13597145  ha-4918992  2018-12-28 00:00:00      B         NaN  3000.0
# 13597154  ha-4918992  2018-12-29 00:00:00      B         NaN  3000.0
# 13597163  ha-4918992  2018-12-30 00:00:00      B         NaN  3000.0
# 13597172  ha-4918992  2018-12-31 00:00:00      B         NaN  3000.0
#
#           Reservation_ID Property ID  Zipcode   Latitude  Longitude
# 13594706             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13594715             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13594724             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13594733             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13594742             NaN  ha-4918992   2141.0  42.371992 -71.082319
# ...                  ...         ...      ...        ...        ...
# 13597136             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13597145             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13597154             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13597163             NaN  ha-4918992   2141.0  42.371992 -71.082319
# 13597172             NaN  ha-4918992   2141.0  42.371992 -71.082319
#
# [275 rows x 10 columns]

# %% [markdown]
# ***

# %% [markdown]
# ## 05 Saving to CSV (Or other formats)

# %%
Available = cambridge_joined.loc[cambridge_joined['Status'] == 'A' ]

# %%
# Export to Csv
Available.to_csv('data\Available_airbnb.csv')

# %%
joined_2018 = daily_2018.merge(monthly_2018[['Property ID', 'Zipcode', 'City', 'Latitude', 'Longitude']], left_on="Property_ID", right_on="Property ID")
joined_2018.head()
# Out:
#    Property_ID                 Date Status Booked_Date  Price  Reservation_ID  \
# 0  ab-10004575  2018-01-01 00:00:00      A         NaN  350.0             NaN
# 1  ab-10004575  2018-01-01 00:00:00      A         NaN  350.0             NaN
# 2  ab-10004575  2018-01-01 00:00:00      A         NaN  350.0             NaN
# 3  ab-10004575  2018-01-01 00:00:00      A         NaN  350.0             NaN
# 4  ab-10004575  2018-01-01 00:00:00      A         NaN  350.0             NaN
#
#    Property ID  Zipcode           City  Latitude  Longitude
# 0  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 1  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 2  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 3  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 4  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297

# %%
blocked = joined_2018.loc[joined_2018['Status'] == 'B' ]

# %%
blocked = booked.drop_duplicates()

# %%
blocked.head()
# Out:
#      Property_ID                 Date Status Booked_Date  Price  \
# 156  ab-10004575  2018-01-14 00:00:00      B         NaN  225.0
# 168  ab-10004575  2018-01-15 00:00:00      B         NaN  225.0
# 180  ab-10004575  2018-01-16 00:00:00      B         NaN  225.0
# 192  ab-10004575  2018-01-17 00:00:00      B         NaN  225.0
# 204  ab-10004575  2018-01-18 00:00:00      B         NaN  225.0
#
#      Reservation_ID  Property ID  Zipcode           City  Latitude  Longitude
# 156             NaN  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 168             NaN  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 180             NaN  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 192             NaN  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297
# 204             NaN  ab-10004575   2130.0  Jamaica Plain  42.31969  -71.11297

# %%
blocked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4128312 entries, 156 to 104900123
# Data columns (total 11 columns):
# Property_ID       object
# Date              object
# Status            object
# Booked_Date       object
# Price             float64
# Reservation_ID    float64
# Property ID       object
# Zipcode           float64
# City              object
# Latitude          float64
# Longitude         float64
# dtypes: float64(5), object(6)
# memory usage: 378.0+ MB

# %%
blocked.to_csv('data\Blocked.csv')

# %%
reserved = joined_2018.loc[joined_2018['Status'] == 'R' ]

# %%
reserved = reserved.drop_duplicates()

# %%
reserved.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1977140 entries, 468 to 104899451
# Data columns (total 11 columns):
# Property_ID       object
# Date              object
# Status            object
# Booked_Date       object
# Price             float64
# Reservation_ID    float64
# Property ID       object
# Zipcode           float64
# City              object
# Latitude          float64
# Longitude         float64
# dtypes: float64(5), object(6)
# memory usage: 181.0+ MB

# %% [markdown]
# ## 06 - 01 More Pandas - Bluebike Data

# %% [markdown]
# Data downloaded from Bluebikes Website <br>
# https://s3.amazonaws.com/hubway-data/index.html <br>
# https://www.bluebikes.com/system-data

# %%
# Download and then read in your data
stations_info = pd.read_csv("data\Hubway_Stations_as_of_July_2017.csv")
stations_info.head()
# Out:
#   Station ID                                    Station   Latitude  Longitude  \
# 0     A32019                           175 N Harvard St  42.363796 -71.129164
# 1     S32035                              191 Beacon St  42.380323 -71.108786
# 2     S32023                                30 Dane St.  42.381001 -71.104025
# 3     M32026  359 Broadway - Broadway at Fayette Street  42.370803 -71.104412
# 4     M32054                           699 Mt Auburn St  42.375002 -71.148716
#
#   Municipality  publiclyExposed  # of Docks
# 0       Boston                1          18
# 1   Somerville                1          15
# 2   Somerville                1          15
# 3    Cambridge                1          23
# 4    Cambridge                1          25

# %%
# here start station = boardings and end station = alightings
trips_sept = pd.read_csv(r"data\201909-bluebikes-tripdata.csv")
trips_sept.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           916  2019-09-01 00:00:21.2560  2019-09-01 00:15:38.0670
# 1           394  2019-09-01 00:00:33.0140  2019-09-01 00:07:07.1410
# 2           480  2019-09-01 00:00:52.4870  2019-09-01 00:08:52.9530
# 3           800  2019-09-01 00:01:05.5390  2019-09-01 00:14:25.8490
# 4           758  2019-09-01 00:01:13.4250  2019-09-01 00:13:52.2810
#
#    start station id                                 start station name  \
# 0                 9                    Commonwealth Ave at Agganis Way
# 1               189                                          Kendall T
# 2                 9                    Commonwealth Ave at Agganis Way
# 3                46  Christian Science Plaza - Massachusetts Ave at...
# 4                56             Dudley Square - Dudley St at Warren St
#
#    start station latitude  start station longitude  end station id  \
# 0               42.351692               -71.119035              33
# 1               42.362428               -71.084955             178
# 2               42.351692               -71.119035              10
# 3               42.343666               -71.085824             199
# 4               42.329843               -71.083866              55
#
#                                    end station name  end station latitude  \
# 0                                    Kenmore Square             42.348706
# 1                   MIT Pacific St at Purrington St             42.359573
# 2                     B.U. Central - 725 Comm. Ave.             42.350406
# 3  Upham's Corner T Stop - Magnolia St at Dudley St             42.318697
# 4                  Boylston St at Massachusetts Ave             42.347265
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -71.097009    4161  Subscriber        2000       1
# 1             -71.101295    5515  Subscriber        1991       1
# 2             -71.108279    3061    Customer        1969       0
# 3             -71.069781    3309  Subscriber        1983       1
# 4             -71.088088     743  Subscriber        1977       1

# %%
trips_sept.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
# Finding out boardings
boardings = trips_sept['start station name'].value_counts()
print(boardings)
# Out:
# MIT at Mass Ave / Amherst St               8470
# Ames St at Main St                         7278
# Central Square at Mass Ave / Essex St      7201
# South Station - 700 Atlantic Ave           5950
# MIT Stata Center at Vassar St / Main St    5911
#                                            ...
# Spring St at Powell St                       14
# Washington St at Walsh Playground            13
# Washington St at Fuller St                   12
# Mobile Temporary Station                     10
# BCBS Quincy                                   3
# Name: start station name, Length: 328, dtype: int64

# %%
# Finding out alightings
alightings = trips_sept['end station name'].value_counts()
print(alightings)
# Out:
# MIT at Mass Ave / Amherst St             8338
# Ames St at Main St                       8156
# Central Square at Mass Ave / Essex St    7237
# Nashua Street at Red Auerbach Way        5572
# Harvard Square at Mass Ave/ Dunster      4879
#                                          ...
# Washington St at Walsh Playground          17
# Washington St at Fuller St                 14
# Spring St at Powell St                      9
# Mobile Temporary Station                    7
# BCBS Quincy                                 3
# Name: end station name, Length: 328, dtype: int64

# %%
# Changing to Datetime format
trips_sept['date']=pd.to_datetime(trips_sept['starttime'])

# %% [markdown]
# ### Taking a week's worth of data

# %%
# Taking 2nd week of September from 9-15th September as 2nd September is a Public Holiday (Labor Day)
# Trips_sub = trips_sept.loc['2019-09-09':'2019-09-15']

secondwk = (trips_sept['date'] >= '2019-09-09') & ( trips_sept['date'] <= '2019-09-15')
trips_sub = trips_sept.loc[secondwk]

trips_sub.head()
# Out:
#        tripduration                 starttime                  stoptime  \
# 88899          1421  2019-09-09 00:00:45.8810  2019-09-09 00:24:27.6630
# 88900           507  2019-09-09 00:00:50.4290  2019-09-09 00:09:17.9590
# 88901           911  2019-09-09 00:01:26.0040  2019-09-09 00:16:37.8620
# 88902           716  2019-09-09 00:01:55.3150  2019-09-09 00:13:51.6210
# 88903            93  2019-09-09 00:02:00.0220  2019-09-09 00:03:33.1480
#
#        start station id start station name  start station latitude  \
# 88899               400   Big Papi Station               42.347345
# 88900               400   Big Papi Station               42.347345
# 88901               400   Big Papi Station               42.347345
# 88902               400   Big Papi Station               42.347345
# 88903               185    Third at Binney               42.365445
#
#        start station longitude  end station id  \
# 88899               -71.100168              37
# 88900               -71.100168             403
# 88901               -71.100168             177
# 88902               -71.100168             105
# 88903               -71.082771             141
#
#                                         end station name  \
# 88899                          New Balance - 20 Guest St
# 88900                            Marion St at Harvard St
# 88901                                    University Park
# 88902  Lower Cambridgeport at Magazine St / Riverside Rd
# 88903                                     Kendall Street
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 88899             42.357329             -71.146735    2593  Subscriber
# 88900             42.339781             -71.121334    2318  Subscriber
# 88901             42.362648             -71.100061    3444  Subscriber
# 88902             42.357219             -71.113872    3074    Customer
# 88903             42.363560             -71.082168    3520  Subscriber
#
#        birth year  gender                    date
# 88899        1996       1 2019-09-09 00:00:45.881
# 88900        1994       1 2019-09-09 00:00:50.429
# 88901        1993       1 2019-09-09 00:01:26.004
# 88902        1994       1 2019-09-09 00:01:55.315
# 88903        1986       2 2019-09-09 00:02:00.022

# %%
boardings_week = trips_sub['start station name'].value_counts()
boardings_week = boardings_week.to_frame(name='boarding_counts').reset_index()
boardings_week = boardings_week.rename(columns= {'index': 'Station'}) 
boardings_week.head()
# Out:
#                                    Station  boarding_counts
# 0                       Ames St at Main St             1750
# 1             MIT at Mass Ave / Amherst St             1619
# 2    Central Square at Mass Ave / Essex St             1408
# 3         South Station - 700 Atlantic Ave             1376
# 4  MIT Stata Center at Vassar St / Main St             1283

# %%
alightings_week = trips_sub['end station name'].value_counts()
alightings_week = alightings_week.to_frame(name='alightings_counts').reset_index()
alightings_week = alightings_week.rename(columns= {'index': 'Station'}) 
alightings_week.head()
# Out:
#                                  Station  alightings_counts
# 0                     Ames St at Main St               1692
# 1           MIT at Mass Ave / Amherst St               1631
# 2  Central Square at Mass Ave / Essex St               1404
# 3      Nashua Street at Red Auerbach Way               1320
# 4       South Station - 700 Atlantic Ave               1073

# %%
# There are 58 stations in cambridge
stations = pd.merge(stations_info, boardings_week, how='inner', on='Station')
stations2 = pd.merge(stations, alightings_week, how='inner', on = 'Station')
cambridge_stations = stations2.loc[stations2['Municipality']=='Cambridge']
cambridge_stations.head()
# Out:
#   Station ID                                    Station   Latitude  Longitude  \
# 2     M32026  359 Broadway - Broadway at Fayette Street  42.370803 -71.104412
# 3     M32054                           699 Mt Auburn St  42.375002 -71.148716
# 4     M32060                              700 Huron Ave  42.380788 -71.154129
# 5     M32058                        84 Cambridgepark Dr  42.393600 -71.143941
# 7     M32046                Alewife MBTA at Steel Place  42.395588 -71.142606
#
#   Municipality  publiclyExposed  # of Docks  boarding_counts  \
# 2    Cambridge                1          23              379
# 3    Cambridge                1          25              107
# 4    Cambridge                1          19               48
# 5    Cambridge                1          25               44
# 7    Cambridge                1          19              116
#
#    alightings_counts
# 2                290
# 3                119
# 4                 56
# 5                 47
# 7                115

# %%
# Export to Csv
cambridge_stations.to_csv('data\cambridge_stations.csv')

# %% [markdown]
# ## 06 - 02 Visualizing with  Matplotlib (Optional)

# %% [markdown]
# Matplotlib is a visualiation library in Python that allows you to visualize huge amounts of data by ploting things like line, bar, scatter plot, histogram etc quickly.
# Sample plots [here](https://matplotlib.org/tutorials/introductory/sample_plots.html#sphx-glr-tutorials-introductory-sample-plots-py).

# %%
import matplotlib.pyplot as plt
# magic function to ensure that your plots are rendered in the notebook
# %matplotlib inline

# %%
cambridge_stations.columns
# Out:
# Index(['Station ID', 'Station', 'Latitude', 'Longitude', 'Municipality',
#        'publiclyExposed', '# of Docks', 'boarding_counts',
#        'alightings_counts'],
#       dtype='object')

# %% [markdown]
# #### Matplotlib's pyplot is the library that Pandas use in their plot function. Pandas' plot is only a convenient shortcut.

# %%
# pandas.DataFrame.plot - https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html
cambridge_stations.plot(kind='scatter',x='boarding_counts',y='alightings_counts',color='blue')

# %%
# Plotting scatter plot with matplotlib
x = cambridge_stations['boarding_counts']
y = cambridge_stations['alightings_counts']

plt.scatter(x,y)
plt.plot(x,y, 'o', color='black')
plt.show()

# %%
# Plotting bar chart with matplotlib
x = cambridge_stations['boarding_counts']
y = cambridge_stations['alightings_counts']

ax = cambridge_stations.plot(kind='bar',x='Station ID',y='boarding_counts',color='blue', fontsize = 30, figsize=(40,10))
ax.legend(fontsize=30)

# %%
# Setting the positions and width for the bars
pos = list(range(len(cambridge_stations['boarding_counts']))) 
width = 0.25 

# Plotting the bars
fig, ax = plt.subplots(figsize=(40,10))

# Create a bar with boarding_counts, in position pos,
plt.bar(pos, cambridge_stations['boarding_counts'], width, alpha=0.5, color='#FFC300') 
     
# Create a bar with alightings_counts in position pos + some width buffer,
plt.bar([p + width for p in pos], cambridge_stations['alightings_counts'], width, alpha=0.5, color='#FF5733') 
    
# Set the position of the x-ticks
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(cambridge_stations['Station ID'], fontsize = 24)
ax.yaxis.set_tick_params(labelsize=24)

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(cambridge_stations['boarding_counts'] + cambridge_stations['alightings_counts'])])

# Rotate Station Names for legibility
plt.xticks(rotation=90)

# Adding the legend and showing the plot
plt.legend(['Boardings', 'Alightings'], loc='upper left', fontsize = 40)
plt.show()
